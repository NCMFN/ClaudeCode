# %% [markdown]
# # 04 - Evaluation and Explainability

# %%
import sys
sys.path.append('.')
from src.evaluation import run_evaluation
from src.utils import plot_degradation_trends
import pandas as pd

# %%
run_evaluation()

# %%
try:
    df = pd.read_parquet('data/processed/test_features.parquet')
    plot_degradation_trends(df)
except:
    pass
