# %% [markdown]
# # 01 - Data Ingestion and EDA
# Predicting Hardware End-of-Life via Multi-Metric Operational Log Analysis

# %%
import sys
sys.path.append('.')
from src.data_loader import load_data, run_eda

# %%
dfs = load_data()
run_eda(dfs)
