# %% [markdown]
# # Phase 2: NTL Raster Preprocessing
# This notebook covers converting HDF-EOS5 to GeoTIFF, applying quality masks, and creating annual median composites.

# %%
from src.ntl_utils import hdf_to_geotiff, create_annual_median
import glob

print("NTL preprocessing utilities available.")
