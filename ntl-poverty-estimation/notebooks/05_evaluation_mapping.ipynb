# %% [markdown]
# # Phase 5: Poverty Heatmap Generation
# This notebook applies the trained model to the full NTL grid to generate a spatial poverty heatmap.

# %%
from src.poverty_mapper import generate_poverty_heatmap

print("Poverty mapping utilities available.")
