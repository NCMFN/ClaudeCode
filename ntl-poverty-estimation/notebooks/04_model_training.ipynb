# %% [markdown]
# # Phase 4: Model Training & Evaluation
# This notebook covers training the Random Forest baseline model, cross-validation, and feature importance.

# %%
from src.model_pipeline import train_and_evaluate

print("Model pipeline utilities available.")
