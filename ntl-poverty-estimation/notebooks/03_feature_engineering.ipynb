# %% [markdown]
# # Phase 3: Feature Engineering
# This notebook covers buffering DHS clusters and extracting zonal statistics from the NTL raster.

# %%
from src.feature_extraction import extract_features

print("Feature extraction utilities available.")
