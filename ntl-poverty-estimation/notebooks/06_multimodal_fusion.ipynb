# %% [markdown]
# # Phase 6: Multimodal Data Fusion
# This notebook covers incorporating MODIS NDVI data via Google Earth Engine as an optional extension.

# %%
from src.multimodal_fusion import fetch_ndvi_data, append_ndvi_stats

print("Multimodal fusion utilities available.")
